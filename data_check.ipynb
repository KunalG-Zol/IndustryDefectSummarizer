# %%
import pandas as pd

# %%
df = pd.read_csv('asrs.csv', low_memory=False)

# %%
print(df.columns.to_list())
# Out:
# ['ACN', 'Time.Year', 'Time.Month', 'Time.Local Time Of Day', 'Place.Locale Reference', 'Place.State Reference', 'Place.Relative Position.Angle.Radial', 'Place.Relative Position.Distance.Nautical Miles', 'Place.Altitude.AGL.Single Value', 'Place.Altitude.MSL.Single Value', 'Place.Latitude / Longitude (UAS)', 'Environment.Flight Conditions', 'Environment.Weather Elements / Visibility', 'Environment.Work Environment Factor', 'Environment.Light', 'Environment.Ceiling', 'Environment.RVR.Single Value', 'Aircraft 1.ATC / Advisory', 'Aircraft 1.Aircraft Operator', 'Aircraft 1.Make Model Name', 'Aircraft 1.Aircraft Zone', 'Aircraft 1.Crew Size', 'Aircraft 1.Operating Under FAR Part', 'Aircraft 1.Flight Plan', 'Aircraft 1.Mission', 'Aircraft 1.Nav In Use', 'Aircraft 1.Flight Phase', 'Aircraft 1.Route In Use', 'Aircraft 1.Airspace', 'Aircraft 1.Maintenance Status.Maintenance Deferred', 'Aircraft 1.Maintenance Status.Records Complete', 'Aircraft 1.Maintenance Status.Released For Service', 'Aircr
# ...

# %%
list(df['Assessments.Primary Problem'].unique())
# Out:
# ['Human Factors',
#  'Airport',
#  'Aircraft',
#  'Weather',
#  'Ambiguous',
#  nan,
#  'Chart Or Publication',
#  'ATC Equipment / Nav Facility / Buildings',
#  'Company Policy',
#  'Environment - Non Weather Related',
#  'Airspace Structure',
#  'Manuals',
#  'Procedure',
#  'Equipment / Tooling',
#  'Incorrect / Not Installed / Unavailable Part',
#  'MEL',
#  'Staffing',
#  'Logbook Entry',
#  'Software and Automation']

# %%
df[df['Assessments.Primary Problem']=='Aircraft']['Report 1.Synopsis']
# Out:
# 12        PRESSURIZATION CTL ON ACR MLG LOST AS ACFT REA...
# 16        ATX SMT GOT GEAR RED WARNING LIGHT ON APCH TO ...
# 18        REPORTER REQUIRED TO FLY AN ACFT THAT HE THOUG...
# 22        GA SMT RIGHT MAIN GEAR COLLAPSED AFTER LNDG. P...
# 25        RIGHT THROTTLE LINKAGE ON AN ATX SMT BROKE WHI...
#                                 ...
# 237594    Air carrier pilot reported there was a fumes e...
# 237619    ATR 72 Captain reported encountering severe in...
# 237644    A320 Captain reported the First Officer was lo...
# 237649    A321 Flight Attendant reported multiple jump s...
# 237653    Air carrier Flight Attendants reported being n...
# Name: Report 1.Synopsis, Length: 51368, dtype: str

# %%
df['Report 1.Synopsis'].iloc[0]
# Out:
# 'AFTER LEAVING FL320 MLG INSTRUCTED TO DES TO FL310 AFTER BEING INITIALLY CLEARED TO FL350. PIC CAPT OBSERVED OPPOSITE DIRECTION TRAFFIC PASS 1 MINUTE LATER AT FL330.'
